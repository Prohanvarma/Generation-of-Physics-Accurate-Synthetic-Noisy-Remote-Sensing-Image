# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread(r"C:\Users\proha\OneDrive\Desktop\computer vision\RAF30JAN2026047471009900060SSANSTUC00GTDB", cv2.IMREAD_GRAYSCALE)

image = cv2.normalize(
    image,
    None,
    0,
    255,
    cv2.NORM_MINMAX
).astype(np.uint8)
